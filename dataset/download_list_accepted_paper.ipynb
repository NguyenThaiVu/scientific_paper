# %% [markdown]
# # Description
#
# In this paper, I will download list of accepted paper from DBLP using DBLP api.

# %%
import os 
import numpy as np
import pandas as pd
import json
from typing import List, Tuple, Dict
import requests
import xml.etree.ElementTree as ET

# %%
LIST_CONF_NAME = ['mlsys']

# %%
def fetch_mlsys_xml(conf_name:str, year:int) -> bytes:
    """
    Fetch the XML data for the specified conference and year.
    """
    url = f"https://dblp.org/db/conf/{conf_name}/{conf_name}{year}.xml"
    resp = requests.get(url)
    resp.raise_for_status()
    return resp.content


def parse_mlsys_xml(xml_string: bytes) -> List[Dict]:
    root = ET.fromstring(xml_string)
    list_papers = []

    for r in root.findall(".//r"):
        inproc = r.find("inproceedings")
        if inproc is not None:
            title = inproc.findtext("title", default="").strip()
            authors = [a.text for a in inproc.findall("author")]
            url = inproc.findtext("ee", default="")
            year = inproc.findtext("year", default="")

            list_papers.append({
                "title": title,
                "authors": authors,
                "year": year,
                "url": url
            })
    return list_papers

# %%
conf_name = "mlsys"
year = 2023

xml_data = fetch_mlsys_xml(conf_name, year)
print(xml_data)
# Out:
# b'<bht key="db/conf/mlsys/mlsys2023.bht" title="MLSys 2023"> \n<h1>6th <ref href="db/conf/mlsys/index.html">MLSys</ref> 2023:\nMiami, FL, USA</h1> <dblpcites><r><proceedings key="conf/mlsys/2023" mdate="2024-06-28">\n<editor pid="s/DXSong">Dawn Song</editor>\n<editor pid="07/3119">Michael Carbin</editor>\n<editor pid="94/8023-1">Tianqi Chen 0001</editor>\n<title>Proceedings of the Sixth Conference on Machine Learning and Systems, MLSys 2023, Miami, FL, USA, June 4-8, 2023</title>\n<booktitle>MLSys</booktitle>\n<publisher>mlsys.org</publisher>\n<year>2023</year>\n<ee type="oa">https://proceedings.mlsys.org/book/2023</ee>\n<url>db/conf/mlsys/mlsys2023.html</url>\n</proceedings>\n</r>\n<r style="ee"><inproceedings key="conf/mlsys/KwonNSYMZSCZVBM23" mdate="2024-06-28">\n<author pid="203/0006">Hyoukjun Kwon</author>\n<author pid="126/3171">Krishnakumar Nair</author>\n<author pid="334/0541">Jamin Seo</author>\n<author pid="314/7067">Jason Yik</author>\n<author pid="68/6394">Debabrata Mohapatra</author>\n<author pid="29/7639">Dongyuan Zhan</author>\n<author pid="07/4893">Jinook Song</author>\n<author pid="226/0276">Peter Capak</author>\n<author pid="23/8011">Peizhao Zhang</author>\n<author pid="44/5953">Peter Vajda</author>\n<author pid="249/5648">Colby R. Banbury</author>\n<author pid="131/5358">Mark Mazumder</author>\n<author pid="96/11241">Liangzhen Lai</author>\n<author pid="19/4292">Ashish Sirasao</author>\n<author pid="50/2421">Tushar Krishna</author>\n<author pid="199/1801">Harshit Khaitan</author>\n<author pid="57/5163">Vikas Chandra</author>\n<author pid="88/2610">Vijay Janapa Reddi</author>\n<title>XRBench: An Extended Reality (XR) Machine Learning Benchmark Suite for the Metaverse.</title>\n<year>2023</year>\n<booktitle>MLSys</booktitle>\n<ee type="oa">https://proceedings.mlsys.org/paper_files/paper/2023/hash/07b7c2f8a6978e376f9656d69619bfbb-Abstract-mlsys2023.html</ee>\n<crossref>conf/mlsys/2023</crossref>\n<url>db/conf/mlsys/mlsys2023.html#KwonNSYMZSCZVBM23</url>\n</inproceedings>\n</r>\n<r style="ee"><inproceedings key="conf/mlsys/WangCCKL23" mdate="2024-06-28">\n<author pid="341/1241">Ewen Wang</author>\n<author pid="182/7612">Boyi Chen</author>\n<author pid="42/1518">Mosharaf Chowdhury</author>\n<author pid="146/0828">Ajay Kannan</author>\n<author pid="378/9730">Franco Liang</author>\n<title>FLINT: A Platform for Federated Learning Integration.</title>\n<year>2023</year>\n<booktitle>MLSys</booktitle>\n<ee type="oa">https://proceedings.mlsys.org/paper_files/paper/2023/hash/0a1603bfce9502551ad89906515b5941-Abstract-mlsys2023.html</ee>\n<crossref>conf/mlsys/2023</crossref>\n<url>db/conf/mlsys/mlsys2023.html#WangCCKL23</url>\n</inproceedings>\n</r>\n<r style="ee"><inproceedings key="conf/mlsys/0001HZ23" mdate="2024-06-28">\n<author pid="122/3833">Zining Zhang 0001</author>\n<author pid="h/BingshengHe">Bingsheng He</author>\n<author pid="93/4085">Zhenjie Zhang</author>\n<title>Practical Edge Kernels for Integer-Only Vision Transformers Under Post-training Quantization.</title>\n<year>2023</year>\n<booktitle>MLSys</booktitle>\n<ee type="oa">https://proceedings.mlsys.org/paper_files/paper/2023/hash/12f429641e5c63a9ca7fd1c5c4804d32-Abstract-mlsys2023.html</ee>\n<crossref>conf/mlsys/2023</crossref>\n<url>db/conf/mlsys/mlsys2023.html#0001HZ23</url>\n</inproceedings>\n</r>\n<r style="ee"><inproceedings key="conf/mlsys/Lamy-Poirier23" mdate="2024-06-28">\n<author pid="232/1823">Joel Lamy-Poirier</author>\n<title>Breadth-First Pipeline Parallelism.</title>\n<year>2023</year>\n<booktitle>MLSys</booktitle>\n<ee type="oa">https://proceedings.mlsys.org/paper_files/paper/2023/hash/24e845415c1486dd2d582a9d639237f9-Abstract-mlsys2023.html</ee>\n<crossref>conf/mlsys/2023</crossref>\n<url>db/conf/mlsys/mlsys2023.html#Lamy-Poirier23</url>\n</inproceedings>\n</r>\n<r style="ee"><inproceedings key="conf/mlsys/ZhaFLBLHNHTK023" mdate="2024-10-24">\n<author pid="167/0903">Daochen Zha</author>\n<author pid="13/263">Louis Feng</author>\n<author pi ...

# %%
list_papers = parse_mlsys_xml(xml_data)

for paper in list_papers:
    print(f"Title: {paper['title']}")
    print(f"Authors: {', '.join(paper['authors'])}")
    print(f"Year: {paper['year']}")
    print(f"URL: {paper['url']}")
    print("-" * 60)
# Out:
# Title: XRBench: An Extended Reality (XR) Machine Learning Benchmark Suite for the Metaverse.
# Authors: Hyoukjun Kwon, Krishnakumar Nair, Jamin Seo, Jason Yik, Debabrata Mohapatra, Dongyuan Zhan, Jinook Song, Peter Capak, Peizhao Zhang, Peter Vajda, Colby R. Banbury, Mark Mazumder, Liangzhen Lai, Ashish Sirasao, Tushar Krishna, Harshit Khaitan, Vikas Chandra, Vijay Janapa Reddi
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/07b7c2f8a6978e376f9656d69619bfbb-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: FLINT: A Platform for Federated Learning Integration.
# Authors: Ewen Wang, Boyi Chen, Mosharaf Chowdhury, Ajay Kannan, Franco Liang
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/0a1603bfce9502551ad89906515b5941-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Practical Edge Kernels for Integer-Only Vision Transformers Under Post-training Quantization.
# Authors: Zining Zhang 0001, Bingsheng He, Zhenjie Zhang
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/12f429641e5c63a9ca7fd1c5c4804d32-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Breadth-First Pipeline Parallelism.
# Authors: Joel Lamy-Poirier
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/24e845415c1486dd2d582a9d639237f9-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Pre-train and Search: Efficient Embedding Table Sharding with Pre-trained Neural Cost Models.
# Authors: Daochen Zha, Louis Feng, Liang Luo, Bhargav Bhushanam, Zirui Liu 0001, Yusuo Hu, Jade Nie, Yuzhen Huang, Yuandong Tian, Arun Kejariwal, Xia Hu 0001
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/2f982f26692c7fd45831598085f02588-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: FedTree: A Federated Learning System For Trees.
# Authors: Qinbin Li, Zhaomin Wu, Yanzheng Cai, Yuxuan Han, Ching Man Yung, Tianyuan Fu, Bingsheng He
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/3430e7055936cb8e26451ed49fce84a6-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Hotline Profiler: Automatic Annotation and A Multi-Scale Timeline for Visualizing Time-Use in DNN Training.
# Authors: Daniel Snider, Fanny Chevalier, Gennady Pekhimenko
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/347330dd540c72b2c9b0cc304bcf43c6-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: On Noisy Evaluation in Federated Hyperparameter Tuning.
# Authors: Kevin Kuo, Pratiksha Thaker, Mikhail Khodak, John Nguyen, Daniel Jiang, Ameet Talwalkar, Virginia Smith
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/3796d87d44d7ee1d9fa2dc38377afa75-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Be Careful with PyPI Packages: You May Unconsciously Spread Backdoor Model Weights.
# Authors: Tianhang Zheng, Hao Lan, Baochun Li
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/3ca528e932d48832288cd329ccfdd420-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: GiPH: Generalizable Placement Learning for Adaptive Heterogeneous Computing.
# Authors: Yi Hu, Chaoran Zhang, Edward Andert, Harshul Singh, Aviral Shrivastava, James Laudon, Yanqi Zhou, Bob Iannucci, Carlee Joe-Wong
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/3e3eec95971350490e37a076fdc100ad-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: SIRIUS: Harvesting Whole-Program Optimization Opportunities for DNNs.
# Authors: Yijin Li, Jiacheng Zhao, Qianqi Sun, Haohui Mai, Lei Chen, Wanlu Cao, Yanfan Chen, Zhicheng Li, Ying Liu, Xinyuan Zhang, Xiyu Shi, Jie Zhao 0002, Jingling Xue, Huimin Cui, Xiaobing Feng 0002
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/3e4e24f7e055320fa54c03f6e816775f-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Adaptive Message Quantization and Parallelization for Distributed Full-graph GNN Training.
# Authors: Borui Wan, Juntao Zhao, Chuan Wu 0001
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/420bcf98bb3615a21468f1efb426e96d-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: PyTorch RPC: Distributed Deep Learning Built on Tensor-Optimized Remote Procedure Calls.
# Authors: Shen Li, Pritam Damania, Luca Wehrstedt, Rohan Varma, Omkar Salpekar, Pavel Belevich, Howard Huang, Yanli Zhao, Lucas Hosseini, Wanchao Liang, Hongyi Jia, Shihao Xu, Satendra Gera, Alisson G. Azzolini, Guoqiang Jerry Chen, Zachary DeVito, Chaoyang He 0001, Amir Ziashahabi, Alban Desmaison, Edward Z. Yang, Gregory Chanan, Brian Vaughan, Manoj Krishnan, Joseph S. Spisak, Salman Avestimehr, Soumith Chintala
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/47d096470b10eba0c1805697c4445101-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Virtual Machine Allocation with Lifetime Predictions.
# Authors: Hugo Barbalho, Patricia Kovaleski, Beibin Li, Luke Marshall, Marco Molinaro 0004, Abhisek Pan, Eli Cortez, Matheus Leao, Harsh Patwari, Zuzu Tang, Larissa Rozales Gonçalves, David Dion, Thomas Moscibroda, Ishai Menache
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/48eb2c79643df5cb7d125945238bd7d0-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Edge Impulse: An MLOps Platform for Tiny Machine Learning.
# Authors: Colby R. Banbury, Vijay Janapa Reddi, Alexander Elium, Shawn Hymel, David Tischler, Daniel Situnayake, Carl Ward, Louis Moreau, Jenny Plunkett, Matthew Kelcey, Mathijs Baaijens, Alessandro Grande, Dmitry Maslov, Arthur Beavis, Jan Jongboom, Jessica Quaye
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/49fe55f5e9574714dda575bfb2177662-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Tutel: Adaptive Mixture-of-Experts at Scale.
# Authors: Changho Hwang, Wei Cui, Yifan Xiong 0001, Ziyue Yang, Ze Liu, Han Hu 0001, Zilong Wang, Rafael Salas, Jithin Jose, Prabhat Ram, Joe Chau, Peng Cheng 0005, Fan Yang 0024, Mao Yang 0004, Yongqiang Xiong
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/5616d34cf8ff73942cfd5aa922842556-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: MegaBlocks: Efficient Sparse Training with Mixture-of-Experts.
# Authors: Trevor Gale, Deepak Narayanan, Cliff Young, Matei Zaharia
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/5a54f79333768effe7e8927bcccffe40-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Safe Optimized Static Memory Allocation for Parallel Deep Learning.
# Authors: Ioannis Lamprou 0001, Zhen Zhang, Javier de Juan, Hang Yang, Yongqiang Lai, Etienne Filhol, Cédric Bastoul
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/676d8419c61f299feb88c28b40edd3b1-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: X-RLflow: Graph Reinforcement Learning for Neural Network Subgraphs Transformation.
# Authors: Guoliang He, Sean Parker, Eiko Yoneki
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/78a9452fec2d8a221ba5a729403d48af-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Reducing Activation Recomputation in Large Transformer Models.
# Authors: Vijay Anand Korthikanti, Jared Casper, Sangkug Lym, Lawrence McAfee, Michael Andersch, Mohammad Shoeybi, Bryan Catanzaro
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/80083951326cf5b35e5100260d64ed81-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: SysNoise: Exploring and Benchmarking Training-Deployment System Inconsistency.
# Authors: Yan Wang 0033, Yuhang Li 0001, Ruihao Gong, Aishan Liu, Yanfei Wang, Jian Hu, Yongqiang Yao, Yunchen Zhang, Tianzi Xiao, Fengwei Yu, Xianglong Liu 0001
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/842bb98e13307da899490002bf2c693f-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Cupcake: A Compression Scheduler for Scalable Communication-Efficient Distributed Training.
# Authors: Zhuang Wang, Xinyu Crystal Wu, Zhaozhuo Xu, T. S. Eugene Ng
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/870ac3ae9e2d5a29fc41e6ad645ded8f-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: HyperGef: A Framework Enabling Efficient Fusion for Hypergraph Neural Network on GPUs.
# Authors: Zhongming Yu, Guohao Dai, Shang Yang, Genghan Zhang, Hengrui Zhang, Feiwen Zhu, June Yang, Jishen Zhao, Yu Wang 0002
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/895783891e093ded4f0c48c250fde92a-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: ApproxCaliper: A Programmable Framework for Application-aware Neural Network Optimization.
# Authors: Yifan Zhao 0004, Hashim Sharif, Peter Pao-Huang, Vatsin Shah, Arun Narenthiran Sivakumar, Mateus Valverde Gasparino, Abdulrahman Mahmoud, Nathan Zhao, Sarita V. Adve, Girish Chowdhary 0001, Sasa Misailovic, Vikram S. Adve
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/89efa87dc8f0a5d18e4ae0a479658f60-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Transcending Runtime-Memory Tradeoffs in Checkpointing by being Fusion Aware.
# Authors: Horace He, Shangdi Yu
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/8a27bb69950c0b46cdb36d10e5514cc8-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Exploiting Hardware Utilization and Adaptive Dataflow for Efficient Sparse Convolution in 3D Point Clouds.
# Authors: Ke Hong, Zhongming Yu, Guohao Dai, Xinhao Yang, Yaoxiu Lian, Zehao Liu, Ningyi Xu, Yuhan Dong, Yu Wang 0002
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/8e3e27d07b3f663b7f85c819b9692163-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Learning to Parallelize with OpenMP by Augmented Heterogeneous AST Representation.
# Authors: Le Chen, Quazi Ishtiaque Mahmud, Hung Phan, Nesreen K. Ahmed, Ali Jannesari
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/8ee477d6175a03d7098fa23641a2d298-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Validating Large Language Models with ReLM.
# Authors: Michael Kuchnik, Virginia Smith, George Amvrosiadis
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/93c7d9da61ccb2a60ac047e92787c3ef-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Communication-Efficient Graph Neural Networks with Probabilistic Neighborhood Expansion Analysis and Caching.
# Authors: Tim Kaler, Alexandros-Stavros Iliopoulos, Philip Murzynowski, Tao B. Schardl, Charles E. Leiserson, Jie Chen 0007
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/9b09f3893ff30373b682bde69082c75b-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: AutoScratch: ML-Optimized Cache Management for Inference-Oriented GPUs.
# Authors: Yaosheng Fu, Evgeny Bolotin, Aamer Jaleel, Gal Dalal, Shie Mannor, Jacob Subag, Noam Korem, Michael Behar, David W. Nellans
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/9d32b9324a89001520ae456b9e5ec73b-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Efficient GPU Kernels for N: M-Sparse Weights in Deep Learning.
# Authors: Bin Lin, Ningxin Zheng, Lei Wang, Shijie Cao, Lingxiao Ma, Quanlu Zhang, Yi Zhu, Ting Cao, Jilong Xue, Yuqing Yang 0001, Fan Yang 0024
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/a10deb4d5227a8ea307ea8ff3cb712f4-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: On Optimizing the Communication of Model Parallelism.
# Authors: Yonghao Zhuang 0001, Lianmin Zheng, Zhuohan Li 0001, Eric P. Xing, Qirong Ho, Joseph Gonzalez 0001, Ion Stoica, Hao Zhang 0025, Hexu Zhao
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/a42cbafcabb6dc7ce77bfe2e80f5c772-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: μ-TWO: 3× Faster Multi-Model Training with Orchestration and Memory Optimization.
# Authors: Sanket Purandare, Abdul Wasay, Animesh Jain, Stratos Idreos
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/a72071d84c001596e97a2c7e1e880559-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Subgraph Stationary Hardware-Software Inference Co-Design.
# Authors: Payman Behnam, Alexey Tumanov, Tushar Krishna, Pranav Gadikar, Yangyu Chen, Jianming Tong, Yue Pan, Abhimanyu Rajeshkumar Bambhaniya, Alind Khare
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/b7e4b7eaab62baab3b2513c28d1c6ee7-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Cuttlefish: Low-Rank Model Training without All the Tuning.
# Authors: Hongyi Wang 0001, Saurabh Agarwal, Pongsakorn U.-Chupala, Yoshiki Tanaka, Eric P. Xing, Dimitris Papailiopoulos
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/c2db3ef0b1ad4c5ec7c3a0a0c6f6c832-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Efficiently Scaling Transformer Inference.
# Authors: Reiner Pope, Sholto Douglas, Aakanksha Chowdhery, Jacob Devlin, James Bradbury, Jonathan Heek, Kefan Xiao, Shivani Agrawal, Jeff Dean
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/c4be71ab8d24cdfb45e3d06dbfca2780-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: RevBiFPN: The Fully Reversible Bidirectional Feature Pyramid Network.
# Authors: Vitaliy Chiley, Vithursan Thangarasa, Abhay Gupta, Anshul Samar, Joel Hestness, Dennis DeCoste
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/c4f3fb058f957d5f753f9f9f0f08d991-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Renee: End-To-End Training of Extreme Classification Models.
# Authors: Vidit Jain, Jatin Prakash, Deepak Saini, Jian Jiao 0007, Ramachandran Ramjee, Manik Varma
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/c62748872b8c4c49799fc0fa0878515f-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Unified Convolution Framework: A compiler-based approach to support sparse convolutions.
# Authors: Jaeyeon Won, Changwan Hong, Charith Mendis, Joel S. Emer, Saman P. Amarasinghe
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/ccf7262fb986e4367ccd3903960c57a0-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: ALCOP: Automatic Load-Compute Pipelining in Deep Learning Compiler for AI-GPUs.
# Authors: Guyue Huang, Yang Bai, Liu Liu 0017, Yuke Wang, Bei Yu 0001, Yufei Ding 0001, Yuan Xie 0001
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/d6cde2c1b161daa31be560d062cf2251-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: GlueFL: Reconciling Client Sampling and Model Masking for Bandwidth Efficient Federated Learning.
# Authors: Shiqi He, Qifan Yan, Feijie Wu, Lanjun Wang, Mathias Lécuyer, Ivan Beschastnikh
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/da5efc7c4014940f21bcb7fdfd4efab1-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: PipeFisher: Efficient Training of Large Language Models Using Pipelining and Fisher Information Matrices.
# Authors: Kazuki Osawa, Shigang Li 0002, Torsten Hoefler
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/dd064459e9ef4100671ba326f0f96f2b-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Building Verified Neural Networks for Computer Systems with Ouroboros.
# Authors: Cheng Tan, Changliu Liu, Zhihao Jia, Tianhao Wei
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/f025a252767e89e63426e42b4716d311-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Uniform Sparsity in Deep Neural Networks.
# Authors: Saurav Muralidharan
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/f54c95da33c8572340f2f4b09b784e78-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: RecD: Deduplication for End-to-End Deep Learning Recommendation Model Training Infrastructure.
# Authors: Mark Zhao, Dhruv Choudhary, Devashish Tyagi, Ajay Somani, Max Kaplan, Sung-Han Lin, Sarunya Pumma, Jongsoo Park, Aarti Basant, Niket Agarwal, Carole-Jean Wu, Christos Kozyrakis
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/f9b15fec25182f2d70af68a39546d60e-Abstract-mlsys2023.html
# ------------------------------------------------------------
# Title: Sparsity-Aware Memory Interface Architecture using Stacked XORNet Compression for Accelerating Pruned-DNN Models.
# Authors: Younghoon Byun, Seungsik Moon, Baeseong Park, Se Jung Kwon, Dongsoo Lee, Gunho Park, Eunji Yoo, Jung Gyu Min, Youngjoo Lee
# Year: 2023
# URL: https://proceedings.mlsys.org/paper_files/paper/2023/hash/ffbefdce6546916e808f5ede76efbe04-Abstract-mlsys2023.html
# ------------------------------------------------------------
