# %% [markdown]
# # Description
#
# In this notebook, I will read and explore the dataset from Semantic Scholar data

# %%
import os 
import time
import gc
import requests
import json
from tqdm import tqdm
import gzip
from zipfile import ZipFile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from urllib.parse import urlparse

# %% [markdown]
# # 1. Read Venue information

# %%
PATH_FOLDER_DATA = '/home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data'
PATH_FILE_VENUE_INFO = os.path.join(PATH_FOLDER_DATA, '20250822_121946_00119_nihdq_f267a37e-fb99-4619-bf9c-ac33bb4ff585.gz')

# %%
# Load gz file
with gzip.open(PATH_FILE_VENUE_INFO, 'rt', encoding='utf-8') as f:
    venue_data = [json.loads(line) for line in f]
print(f"Number of venues: {len(venue_data)}")

# %%
# Convert the list of dict to DataFrame
venue_df = pd.DataFrame(venue_data)
print(f"Shape of venue DataFrame: {venue_df.shape}")
venue_df.head(1)

# %%
STOPWORDS = {"the","a","an","of","on","in","for","and","to","at","is","are","about","with","by","from","as","into","via"}

def normalize_venue(s: str) -> str:
    if not isinstance(s, str):
        return ""
    s = s.lower().strip()
    s = s.replace("&", " and ")
    s = re.sub(r"\(.*?\)", " ", s)          # drop parenthetical parts
    s = re.sub(r"\b\d{4}\b", " ", s)        # drop years like 2025
    s = re.sub(r"[^a-z0-9\s]", " ", s)      # drop punctuation
    tokens = re.findall(r"[a-z0-9]+", s)

    # drop generic words and venue boilerplate
    cleaned = [t for t in tokens if t not in STOPWORDS]

    # canonical form: sort token set to ignore order/duplicates
    return " ".join(sorted(set(cleaned)))

# %%
# name_journal = 'Computer Vision and Pattern Recognition'.lower()
name_journal = 'International Conference on Machine Learning'
name_journal = normalize_venue(name_journal)

venue_df[venue_df['name'].apply(lambda x: normalize_venue(x) == name_journal)]

# %%
# Save venue data to CSV
venue_df.to_parquet(os.path.join(PATH_FOLDER_DATA, 'venue_info.parquet'), index=False)

# %% [markdown]
# # 2. Read paper info

# %% [markdown]
# ## 2.1. Load paper from raw file and save to `parquet`

# %%
PATH_FOLDER_DATA = '/home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data'

PATH_FILE_PAPER_DATA = os.path.join(PATH_FOLDER_DATA, '20250822_070444_00023_vs6f6_06af69c5-002b-4503-9557-233755e9ad9b.gz')

PATH_FOLDER_DATA_PROCESSED = '/home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data_processed'

LIST_SELECTED_FIELDS = ['title', 'authors', 'year', 'citationcount',\
                        'venue', 'publicationvenueid', 'publicationdate']

# %%
list_file_downloaded = os.listdir(PATH_FOLDER_DATA)
list_file_downloaded = sorted(list_file_downloaded)
print(f"Number of downloaded files: {len(list_file_downloaded)}")
# Out:
# Number of downloaded files: 60

# %%
CHUNK_SIZE = 500_000

for idx_file, file_name in enumerate(list_file_downloaded):
    if not file_name.endswith('.gz'):
        continue
    path_file = os.path.join(PATH_FOLDER_DATA, file_name)
    print(f"{idx_file}. Processing file: {path_file}")

    rows = []
    try:
        with gzip.open(path_file, 'rt', encoding='utf-8') as f:
            for i, line in enumerate(f):
                try:
                    line_json = json.loads(line)
                
                    # Extract paper ID from semantic url
                    url = line_json.get("url", "")
                    paper_id = urlparse(url).path.split("/")[-1] if url else ""
                    
                    row = {k: line_json.get(k, "") for k in LIST_SELECTED_FIELDS}
                    row["semantic_id"] = paper_id
                    rows.append(row)

                    if (i > 0) and (i % CHUNK_SIZE == 0):
                        output_file_parquet_name = f"paper_file_{idx_file}_chunk_{i//CHUNK_SIZE}.parquet"
                        path_output_file_parquet = os.path.join(PATH_FOLDER_DATA_PROCESSED, output_file_parquet_name)
                        pd.DataFrame(rows).to_parquet(path_output_file_parquet)
                        rows.clear()
                        time.sleep(3)  # avoid overwhelming the system
                        gc.collect() 
                except:
                    continue
                
        # Save any remaining rows
        if (rows) and (len(rows) > 0):
            output_file_parquet_name = f"paper_file_{idx_file}_chunk_final.parquet"
            path_output_file_parquet = os.path.join(PATH_FOLDER_DATA_PROCESSED, output_file_parquet_name)
            pd.DataFrame(rows).to_parquet(path_output_file_parquet)
            rows.clear()
            time.sleep(3)
            gc.collect()

        print(f"Finished processing file: {path_file} \n")
    except (gzip.BadGzipFile, OSError) as e:
        print(f"[fatal] Cannot read {path_file}: {e}. Skipping file.")
        continue
# Out:
# 0. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_06af69c5-002b-4503-9557-233755e9ad9b.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_06af69c5-002b-4503-9557-233755e9ad9b.gz
#
# 1. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_06fa50bb-9d50-41ca-b2bc-c1fcacfd4785.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_06fa50bb-9d50-41ca-b2bc-c1fcacfd4785.gz
#
# 2. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_07ac81a4-bf8d-4d9e-9c53-78687adb27a7.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_07ac81a4-bf8d-4d9e-9c53-78687adb27a7.gz
#
# 3. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_07f2279a-103e-455b-b08f-3ee7627c5452.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_07f2279a-103e-455b-b08f-3ee7627c5452.gz
#
# 4. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_0b3b75bd-8cf7-45af-be8b-aa3e67d1c5d9.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_0b3b75bd-8cf7-45af-be8b-aa3e67d1c5d9.gz
#
# 5. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_103e1407-44c3-4c06-9891-9e1e294a63e2.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_103e1407-44c3-4c06-9891-9e1e294a63e2.gz
#
# 6. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_10a237ee-7f97-492a-82d4-74755dbb8e25.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_10a237ee-7f97-492a-82d4-74755dbb8e25.gz
#
# 7. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_13e58ca0-a60d-48ae-bc77-961e1764fd67.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_13e58ca0-a60d-48ae-bc77-961e1764fd67.gz
#
# 8. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_19d2fa1e-dd6c-4ed9-b37a-e62fc296e661.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_19d2fa1e-dd6c-4ed9-b37a-e62fc296e661.gz
#
# 9. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_1d05b6c8-dcd5-415e-bb24-2e32ad1c7cb2.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_1d05b6c8-dcd5-415e-bb24-2e32ad1c7cb2.gz
#
# 10. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_1ec7b80f-0bb7-427f-b18f-b584ded27f24.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_1ec7b80f-0bb7-427f-b18f-b584ded27f24.gz
#
# 11. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_21761c5e-0de2-472b-9e70-28564c96aa45.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_21761c5e-0de2-472b-9e70-28564c96aa45.gz
#
# 12. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_276c7a93-f45c-4555-b482-2b5c7ffc3f95.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_276c7a93-f45c-4555-b482-2b5c7ffc3f95.gz
#
# 13. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_2cd42a9c-a23e-401b-a108-365bf332a32b.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_2cd42a9c-a23e-401b-a108-365bf332a32b.gz
#
# 14. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_2f2bad6a-3cb8-42d5-af31-b9d01da8f563.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_2f2bad6a-3cb8-42d5-af31-b9d01da8f563.gz
#
# 15. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_32edb0d6-beb3-439d-b3be-0abf596f0ee0.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_32edb0d6-beb3-439d-b3be-0abf596f0ee0.gz
#
# 16. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_36e2b9d5-df81-47f2-a26d-9de6177ccd31.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_36e2b9d5-df81-47f2-a26d-9de6177ccd31.gz
#
# 17. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_3f0e6ef5-717d-45c6-b249-695a41a3b21b.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_3f0e6ef5-717d-45c6-b249-695a41a3b21b.gz
#
# 18. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_48c4a03b-6c20-4e31-baa6-c8ed84e33970.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_48c4a03b-6c20-4e31-baa6-c8ed84e33970.gz
#
# 19. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_4aed86de-4b55-4446-964e-373361191844.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_4aed86de-4b55-4446-964e-373361191844.gz
#
# 20. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_4af5f5bb-8ee8-493e-aaea-9c07f9b2c68c.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_4af5f5bb-8ee8-493e-aaea-9c07f9b2c68c.gz
#
# 21. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_507ee55e-cb78-471d-866b-97c7d8bdffff.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_507ee55e-cb78-471d-866b-97c7d8bdffff.gz
#
# 22. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_51ad87fa-8557-49ad-8cb9-d56163784794.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_51ad87fa-8557-49ad-8cb9-d56163784794.gz
#
# 23. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_5b7bbf91-0b02-4a19-8c17-c91bf1468de1.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_5b7bbf91-0b02-4a19-8c17-c91bf1468de1.gz
#
# 24. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_606000c8-bd91-4137-abe0-7faf32a5170b.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_606000c8-bd91-4137-abe0-7faf32a5170b.gz
#
# 25. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_61c25d3b-ea39-4848-9502-ffa27f4118e9.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_61c25d3b-ea39-4848-9502-ffa27f4118e9.gz
#
# 26. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_6605c929-c123-4926-ac0c-31293ac6c152.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_6605c929-c123-4926-ac0c-31293ac6c152.gz
#
# 27. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_6791b856-47a9-437e-a3a4-71ca1ae11116.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_6791b856-47a9-437e-a3a4-71ca1ae11116.gz
#
# 28. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_679539dc-7ccd-494a-8f9d-db3ac33c22aa.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_679539dc-7ccd-494a-8f9d-db3ac33c22aa.gz
#
# 29. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_69f89c4c-86ee-4a4d-87e4-a45299d9a96e.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_69f89c4c-86ee-4a4d-87e4-a45299d9a96e.gz
#
# 30. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_72462267-16c6-458d-a378-bf9cbde5b298.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_72462267-16c6-458d-a378-bf9cbde5b298.gz
#
# 31. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_74ca25a1-49d4-4692-81cf-3db51bde46bf.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_74ca25a1-49d4-4692-81cf-3db51bde46bf.gz
#
# 32. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_758fe19c-1700-4eba-90e8-fb31355a5857.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_758fe19c-1700-4eba-90e8-fb31355a5857.gz
#
# 33. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_811290b5-2761-4aa9-9083-d4fe8d80ad46.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_811290b5-2761-4aa9-9083-d4fe8d80ad46.gz
#
# 34. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_81ea214b-8f41-4130-9514-aeea12c7bcae.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_81ea214b-8f41-4130-9514-aeea12c7bcae.gz
#
# 35. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_8d747d22-fd58-439c-82a8-a590c64e8da6.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_8d747d22-fd58-439c-82a8-a590c64e8da6.gz
#
# 36. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_9283feed-83f0-4048-977d-c54668a285e5.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_9283feed-83f0-4048-977d-c54668a285e5.gz
#
# 37. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_94c03173-811c-4f4f-98a4-02544d7f8f40.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_94c03173-811c-4f4f-98a4-02544d7f8f40.gz
#
# 38. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_95f46123-222a-4407-b161-de27b8a25c75.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_95f46123-222a-4407-b161-de27b8a25c75.gz
#
# 39. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_96c23834-9b56-4bd9-be1e-fdb2287a402c.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_96c23834-9b56-4bd9-be1e-fdb2287a402c.gz
#
# 40. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_9fa3c440-6d11-4346-bb21-cd0ed5293b79.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_9fa3c440-6d11-4346-bb21-cd0ed5293b79.gz
#
# 41. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_a44748d2-3f4a-4c7b-b061-d884546e872e.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_a44748d2-3f4a-4c7b-b061-d884546e872e.gz
#
# 42. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_a57c837b-d854-4803-b1ff-434dba2e98e2.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_a57c837b-d854-4803-b1ff-434dba2e98e2.gz
#
# 43. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_a6c75bb4-c92a-4e4c-90a5-c0afe5313861.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_a6c75bb4-c92a-4e4c-90a5-c0afe5313861.gz
#
# 44. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_ac31aff0-d6ee-4761-bc45-a3e44a9f795d.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_ac31aff0-d6ee-4761-bc45-a3e44a9f795d.gz
#
# 45. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_b1530ce9-ac0d-4e9e-88f4-952891bd14b2.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_b1530ce9-ac0d-4e9e-88f4-952891bd14b2.gz
#
# 46. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_b3733b48-f66b-472f-a8a7-43e4c7d82a67.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_b3733b48-f66b-472f-a8a7-43e4c7d82a67.gz
#
# 47. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_b99d838f-e877-47cf-9706-e808d49a7bbf.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_b99d838f-e877-47cf-9706-e808d49a7bbf.gz
#
# 48. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_badcfef4-f567-4a61-8eb2-d2a1bb3cf693.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_badcfef4-f567-4a61-8eb2-d2a1bb3cf693.gz
#
# 49. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_d0d7d2eb-bbc4-495e-84b1-4c0efc56ce81.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_d0d7d2eb-bbc4-495e-84b1-4c0efc56ce81.gz
#
# 50. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_d7a8596d-2793-4741-9806-a2eaa97060f4.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_d7a8596d-2793-4741-9806-a2eaa97060f4.gz
#
# 51. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_dc62b1c7-0ebb-47b2-b37b-46ad8cc6b9c1.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_dc62b1c7-0ebb-47b2-b37b-46ad8cc6b9c1.gz
#
# 52. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_de9aa9a2-d701-465c-b0be-68a9a9a1253e.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_de9aa9a2-d701-465c-b0be-68a9a9a1253e.gz
#
# 53. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_e420bd34-43d9-41e7-b737-79fbf5f0870e.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_e420bd34-43d9-41e7-b737-79fbf5f0870e.gz
#
# 54. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_e6900ec0-4a8a-457f-bdc9-926f0032e189.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_e6900ec0-4a8a-457f-bdc9-926f0032e189.gz
#
# 55. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_ebaac18b-0364-48ac-b7f2-0f5e3829584e.gz
# Finished processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_ebaac18b-0364-48ac-b7f2-0f5e3829584e.gz
#
# 56. Processing file: /home/thaiv7/Desktop/python-project/scientific_paper/dataset/data/semantic_scholar_data/20250822_070444_00023_vs6f6_f10ba4f8-5832-4439-bc56-b09cf93cb0c8.gz

# %% [markdown]
# ## 2.2. Load paper and query additional data
#
# We get reference of paper.

# %%
path_file_parquet = os.path.join(PATH_FOLDER_DATA_PROCESSED, 'papers_part_1.parquet')
df = pd.read_parquet(path_file_parquet)
print(f"DataFrame shape: {df.shape}")
df.head(2)
# Out:
# DataFrame shape: (500001, 8)
#                                                title  \
# 0  Refinement of the mental model of a solution b...
# 1  Late swing or early stance? A narrative review...
#
#                                              authors    year  citationcount  \
# 0  [{'authorId': '2329932387', 'name': 'S. Chalyi...  2024.0              0
# 1  [{'authorId': '1398183854', 'name': 'Claire Ke...  2019.0             90
#
#                                                venue  \
# 0          Management Information System and Devises
# 1  Scandinavian Journal of Medicine & Science in ...
#
#                      publicationvenueid publicationdate  \
# 0                                  None      2024-12-04
# 1  5712d901-2da7-4216-814d-2f143495e778      2019-08-01
#
#                                 semantic_id
# 0  8b6591b716d5071785ebefd57aa14ef7a3dc495e
# 1  954fdea23e1970fb0b20a6c9343a0e2179ea4e83

# %%
def get_references(paper_id, fields="paperId", limit=100, timeout=30):
    """
    Fetch reference paperIds for a given Semantic Scholar paper_id.

    Args:
        paper_id (str): Semantic Scholar Paper ID, DOI, ArXiv ID, etc.
        fields (str): Fields to request (default: "paperId").
        limit (int): Max refs per call (API limit = 100).
        timeout (int): Request timeout in seconds.

    Returns:
        list[str]: List of cited paperIds (could be empty).
    """
    url = f"https://api.semanticscholar.org/graph/v1/paper/{paper_id}/references"
    params = {"fields": fields, "limit": limit}

    try:
        resp = requests.get(url, params=params, timeout=timeout)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as e:
        print(f"HTTP error for paper {paper_id}: {e}")
        return []
    except requests.exceptions.RequestException as e:
        print(f"Network error for paper {paper_id}: {e}")
        return []

    try:
        data = resp.json()
    except ValueError:
        print(f"Invalid JSON for paper {paper_id}")
        return []

    refs = data.get("data", [])
    if not refs:
        return []
    paper_ids = [r.get("citedPaper", {}).get("paperId") for r in refs if r.get("citedPaper")]
    return [pid for pid in paper_ids if pid]

# %%
list_ref_paper = get_references("954fdea23e1970fb0b20a6c9343a0e2179ea4e83")
list_ref_paper
# Out:
# []
